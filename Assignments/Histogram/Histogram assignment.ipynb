# %%
#load the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#Import the dataset
df_age_participants=pd.read_csv("//Users//motolanikay-salami//Downloads//histogram_survey_data.csv")

# %%
df_age_participants
# Out:
#              ID  Sex  Marital status  Age  Education  Income  Occupation  \
# 0     100000001    0               0   67          2  124670           1
# 1     100000002    1               1   22          1  150773           1
# 2     100000003    0               0   49          1   89210           0
# 3     100000004    0               0   45          1  171565           1
# 4     100000005    0               0   53          1  149031           1
# ...         ...  ...             ...  ...        ...     ...         ...
# 1995  100001996    1               0   47          1  123525           0
# 1996  100001997    1               1   27          1  117744           1
# 1997  100001998    0               0   31          0   86400           0
# 1998  100001999    1               1   24          1   97968           0
# 1999  100002000    0               0   25          0   68416           0
#
#       Settlement size
# 0                   2
# 1                   2
# ...

# %%
#Plot the chart
sns.set_style("white")
plt.figure(figsize=(8,6))
plt.hist(df_age_participants["Age"],
         bins=10,
        color="#CD0000")
plt.title("Geodemographic features of Participants", fontsize=14, fontweight="bold")
plt.xlabel("Ages of Participants")
plt.ylabel("Number of Participants")
sns.despine()
plt.show()
plt.savefig("Histogram.png")
